# %%
import pandas as pd 
from sqlalchemy import create_engine
df=pd.read_csv("C:/Users/preet/traffic_stopss.csv")
df
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_2656\226464548.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("C:/Users/preet/traffic_stopss.csv")
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01  00:00:00       Canada             M              59
# 1      2020-01-01  00:01:00        India             M              35
# 2      2020-01-01  00:02:00          USA             M              26
# 3      2020-01-01  00:03:00       Canada             M              26
# 4      2020-01-01  00:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
# ...

# %%
print(df.isnull().sum())
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
print(df["search_type"].unique())
print(df["search_type"].value_counts())
# Out:
# ['Vehicle Search' 'Frisk' nan]
# search_type
# Frisk             21971
# Vehicle Search    21847
# Name: count, dtype: int64

# %% [markdown]
# # 33% of nan value hence the colunm is not affecting the data and requried for analysis hence making it as unkown

# %%
df = df.drop_duplicates()

# %%
df = df.fillna('Unknown')
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01  00:00:00       Canada             M              59
# 1      2020-01-01  00:01:00        India             M              35
# 2      2020-01-01  00:02:00          USA             M              26
# 3      2020-01-01  00:03:00       Canada             M              26
# 4      2020-01-01  00:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
df = df.dropna(axis=1, how='all')

# %%
pip install pymysql

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:2296@localhost/traffic_db")
df.to_sql('traffic_stopss', con=engine, if_exists='replace', index=False)

print("✅ Data successfully inserted into SQL database!")
# Out:
# ✅ Data successfully inserted into SQL database!

# %%
print(df[['driver_age_raw', 'driver_age']].describe())
# Out:
#        driver_age_raw   driver_age
# count    65538.000000  65538.00000
# mean        49.055998     49.11221
# std         18.174699     18.15012
# min         18.000000     18.00000
# 25%         33.000000     34.00000
# 50%         49.000000     49.00000
# 75%         65.000000     65.00000
# max         80.000000     80.00000

# %%
df.drop('driver_age_raw', axis=1, inplace=True)

# %%
df["violation_raw"].unique()
# Out:
# array(['Drunk Driving', 'Other', 'Signal Violation', 'Speeding',
#        'Seatbelt'], dtype=object)

# %%
df["violation"].unique()
# Out:
# array(['Speeding', 'Other', 'DUI', 'Seatbelt', 'Signal'], dtype=object)

# %%
df.drop('violation_raw', axis=1, inplace=True)
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01  00:00:00       Canada             M          19
# 1      2020-01-01  00:01:00        India             M          58
# 2      2020-01-01  00:02:00          USA             M          76
# 3      2020-01-01  00:03:00       Canada             M          76
# 4      2020-01-01  00:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India             F          48
# 65534  2020-02-15  12:14:00       Canada             F          35
# 65535  2020-02-15  12:15:00          USA             M          41
# 65536  2020-02-15  12:16:00       Canada             F          63
# 65537  2020-02-15  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 10.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
# ...

# %%
engine = engine = create_engine("mysql+pymysql://root:2296@localhost:3306/preeti")
df.to_sql('trafficstop', engine, if_exists='replace', index=False)

result_df = pd.read_sql("SELECT * FROM trafficstop", engine)
print(result_df)
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01  00:00:00       Canada             M              59
# 1      2020-01-01  00:01:00        India             M              35
# 2      2020-01-01  00:02:00          USA             M              26
# 3      2020-01-01  00:03:00       Canada             M              26
# 4      2020-01-01  00:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
df['stop_time'] = pd.to_datetime(df['stop_time'], format='%H:%M:%S').dt.time

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01  00:00:00       Canada             M              59
# 1      2020-01-01  00:01:00        India             M              35
# 2      2020-01-01  00:02:00          USA             M              26
# 3      2020-01-01  00:03:00       Canada             M              26
# 4      2020-01-01  00:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector




mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="2296",


)


print(mydb)
mycursor = mydb.cursor(buffered=True)
